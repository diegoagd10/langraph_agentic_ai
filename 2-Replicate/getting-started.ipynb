# %%
import os
from dotenv import load_dotenv

load_dotenv()
os.environ['REPLICATE_API_TOKEN'] = os.getenv('REPLICATE_API_TOKEN') # type: ignore

# %%
from langchain_community.llms import Replicate

model = Replicate(model="ibm-granite/granite-4.0-h-small")

# %%
prompt = """\
<|start_of_role|>user<|end_of_role|>\
Tell a story about a duck who likes french fries.<|end_of_text|>
<|start_of_role|>assistant<|end_of_role|>"""

response = model.invoke(prompt)
print(response)
# Out:
# Once upon a time, in a serene pond nestled in the heart of a lush green park, there lived a peculiar duck named Pierre. Unlike his fellow ducks who were content with their diet of aquatic plants, insects, and the occasional bread crumbs tossed by park visitors, Pierre had a rather unusual craving: he loved french fries.
#
# Pierre's fascination with french fries began one sunny afternoon when he was waddling along the edge of the pond. He noticed a group of people gathered around a picnic table, laughing and enjoying their lunch. Among the various foods, a golden, crispy french fry slipped from someone's hand and fell to the ground, right at Pierre's feet.
#
# Curiosity piqued, Pierre cautiously approached the fry. He had never seen anything like it before. It was long, thin, and had a delightful aroma that made his beak tingle. Without hesitation, Pierre pecked at the fry, and to his surprise, he found it delicious. The crispy exterior gave way to a soft, warm interior, and Pierre was instantly hooked.
#
# From that day forward, Pierre made it his mission to find more french fries. He would spend hours waddling around the park, observing people and their eating habits. He learned that french fries were often served with burgers, hot dogs, and other human foods. Pierre knew he couldn't ask the humans for fries directly, so he devised a clever plan.
#
# Pierre noticed that the park had a small café near the pond, where people often bought snacks and drinks. He watched as the café staff prepared food and noticed that sometimes, a few french fries would accidentally fall on the ground. Pierre would quickly snatch them up before anyone else could.
#
# As word spread among the park's ducks about Pierre's newfound love for french fries, some of his friends became curious. They would gather around Pierre, watching him waddle away with a french fry in his beak, their eyes filled with envy and admiration.
#
# Pierre's obsession with french fries grew stronger with each passing day. He would spend hours dreaming about the perfect fry – crispy on the outside, soft on the inside, and seasoned just right. He even started to imagine what it would be like to have his own french fry farm, where he could grow his own potatoes and fry them to perfection.
#
# One day, as Pierre was waddling along the edge of the pond, he overheard a conversation between two park visitors. They were discussing a new restaurant that had opened nearby, specializing in gourmet french fries. Pierre's heart skipped
